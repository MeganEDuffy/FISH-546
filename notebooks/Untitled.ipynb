# %%
# !date
# Out:
# Tue Dec  6 12:43:11 PST 2016

# %%
# !system_profiler
# Out:
# Accessibility:
#
#     Accessibility Information:
#
#       Cursor Magnification: Off
#       Display: Black on White
#       Flash Screen: Off
#       Mouse Keys: Off
#       Slow Keys: Off
#       Sticky Keys: Off
#       VoiceOver: Off
#       Zoom Mode: Full Screen
#       Contrast: 0
#       Keyboard Zoom: Off
#       Scroll Zoom: Off
#
# Applications:
#
#     OSB 402:
#
#       Version: 12
#       Obtained from: Unknown
#       Last Modified: 7/30/16, 8:17 PM
#       Kind: Intel
#       64-Bit (Intel): Yes
#       Location: /Users/meganduffy/Library/Printers/OSB 402.app
#
#     TeamViewer:
#
#       Version: 11.0.59131
#       Obtained from: Identified Developer
#       Last Modified: 5/2/16, 8:51 AM
#       Kind: Intel
#       64-Bit (Intel): Yes
#       Signed by: Developer ID Application: TeamViewer GmbH, Developer ID Certification Authority, Apple Root CA
#       Location: /Applications/TeamViewer.app
#
#     Google Chrome:
#
#       Version: 54.0.2840.98
# ...
